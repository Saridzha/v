# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
#!pip list

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#!pip install openpyxl

# %%
df = pd.read_excel('КР-1.xlsx', sheet_name='Вар (6)')

# %%
df
# Out:
#     Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# 0                        9.00     1                                   1
# 1                       22.00     1                                   1
# 2                       13.00     1                                   1
# 3                       18.00     1                                   1
# 4                       25.00     1                                   1
# ..                        ...   ...                                 ...
# 64                      40.78     1                                   3
# 65                      21.50     1                                   2
# 66                     115.23     1                                   1
# 67                      34.80     1                                   2
# 68                      22.00     1                                   2
#
#             Тип  Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Торговельна площа, кв. м.           69 non-null     float64
#  1   Этаж                                69 non-null     int64
#  2   Количество сотрудников в магазине   69 non-null     int64
#  3   Тип                                 69 non-null     object
#  4   Рейтинг в гуглі                     69 non-null     float64
#  5   Количество чеков в месяц            69 non-null     float64
#  6   Средний чек                         62 non-null     float64
#  7   Середній дохід наелення,грн         64 non-null     float64
#  8   Населення середнє                   64 non-null     float64
#  9   Фастфуд                             69 non-null     int64
#  10  Кава на виніс                       69 non-null     int64
# ...

# %% [markdown]
# В таких показателях как: средний чек, средний доход населения и население среднее есть пропущенные значения.

# %%
df['Торговельна площа, кв. м.'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Гистограмма показывает, что больше 25 обьектов имеют торговую площадь 20-30 кв.м., 30-50 кв.м. - 29 обьектов, остальные имеют площадь или меньше 20, или больше 50 (кв.м)

# %%
df['Этаж'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Все магазины имеют 1 этаж

# %%
df['Рейтинг в гуглі'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство магазинов имеют рейтинг в гугле 3,75 и выше

# %%
df['Количество чеков в месяц'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# В 15 магазинах количесто чеков в месяц колеблется от 5750 до 7500

# %%
df['Количество сотрудников в магазине'].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\Saridzha\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\Saridzha\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\Saridzha\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Количество сотрудников в магазине'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['Средний чек'].plot(kind = 'hist')

# %% [markdown]
# Чаще всего средний чек лежит в пределах от 90 до 100 у.е.

# %%
df['Середній дохід наелення,грн'].plot(kind = 'hist')

# %% [markdown]
# По гистограмме можно сделать вывод, что средний доход населения - 11000-15000 грн

# %%
df['Населення середнє'].plot(kind = 'hist')

# %% [markdown]
# Среднее население распределилось по гистограмме без больших разрывов

# %%
dfr = df.drop(['Этаж'], axis='columns', inplace=False)
dfr.shape

# %%
df.describe()

# %% [markdown]
# В среднем магазины имеют торговую площадь 34.872 кв.м., количество чеков - 7105, а средний доход населения - 11306.84грн. Стандартные отклонения по данным показателям равны 21.7, 4052,58 и 2438.7 соответственно. Минимальные значения для каждого из значений написаны в строке "min", а максимальные соответсвенно в строке с названием "max". С помощью строки минимальных значений можно сделать вывод, что существует ошибка ввода для значений "Средний доход населения" и "население среднее", то есть в этих полях есть пропущенные значения.

# %%
# Mistakes Deleting
df = df.loc[df['Середній дохід наелення,грн'] > 6000]
df = df.loc[df['Населення середнє'] > 4]

# %%
df
# Out:
#     Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# 0                        9.00     1                                   1
# 1                       22.00     1                                   1
# 2                       13.00     1                                   1
# 3                       18.00     1                                   1
# 4                       25.00     1                                   1
# ..                        ...   ...                                 ...
# 64                      40.78     1                                   3
# 65                      21.50     1                                   2
# 66                     115.23     1                                   1
# 67                      34.80     1                                   2
# 68                      22.00     1                                   2
#
#             Тип  Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# ...

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# Торговельна площа, кв. м.             0
# Этаж                                  0
# Количество сотрудников в магазине     0
# Тип                                   0
# Рейтинг в гуглі                       0
# Количество чеков в месяц              0
# Средний чек                           7
# Середній дохід наелення,грн           5
# Населення середнє                     5
# Фастфуд                               0
# Кава на виніс                         0
# Піцерія                               0
# Магістральна вулиця                   0
# Внутрішньоквартальна дорога           0
# dtype: int64

# %%
df.dtypes
# Out:
# Торговельна площа, кв. м.             float64
# Этаж                                    int64
# Количество сотрудников в магазине       int64
# Тип                                    object
# Рейтинг в гуглі                       float64
# Количество чеков в месяц              float64
# Средний чек                           float64
# Середній дохід наелення,грн           float64
# Населення середнє                     float64
# Фастфуд                                 int64
# Кава на виніс                           int64
# Піцерія                                 int64
# Магістральна вулиця                     int64
# Внутрішньоквартальна дорога             int64
# dtype: object

# %%
#!pip install sklearn

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Торговельна площа, кв. м.             0
# Этаж                                  0
# Количество сотрудников в магазине     0
# Тип                                   0
# Рейтинг в гуглі                       0
# Количество чеков в месяц              0
# Средний чек                           0
# Середній дохід наелення,грн           0
# Населення середнє                     0
# Фастфуд                               0
# Кава на виніс                         0
# Піцерія                               0
# Магістральна вулиця                   0
# Внутрішньоквартальна дорога           0
# dtype: int64

# %%
#!pip install seaborn

# %%
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
df = outliers(df)
df.describe()
# Out:
# C:\Users\Julia\AppData\Local\Temp/ipykernel_12248/2731454419.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std()
# C:\Users\Julia\AppData\Local\Temp/ipykernel_12248/2731454419.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std()
#        Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# ...

# %%
df3 = df[['Тип']]
info = []
for column in df3.columns:
        vals = {"col": column,
                "nunique": df3[column].nunique(),
                "unique": df3[column].unique(),
                "type": df3[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#    col  nunique                                             unique    type
# 0  Тип        5  [Соціальний, Стандартний, Преміальний, Стандар...  object

# %%
fm = {'Соціальний':0,'Преміальний':1,'Стандартний':2,'Соціальний Плюс':3,'Стандарт Плюс':4}
df['Тип'] = df['Тип'].map(fm)
df
# Out:
# C:\Users\Julia\AppData\Local\Temp/ipykernel_12248/393438486.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Тип'] = df['Тип'].map(fm)
#     Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   Тип  \
# 0                    9.000000     1                                   1    0
# 1                   22.000000     1                                   1    0
# 2                   13.000000     1                                   1    0
# 3                   18.000000     1                                   1    2
# 4                   25.000000     1                                   1    0
# ..                        ...   ...                                 ...  ...
# ...

# %%
import seaborn as sns
corrmat = dfr.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [raw]
# Наибольшую корреляцию с количеством чеков в месяц даёт количество сотрудников в магазине. Таким образом, нужно строить однофакторную модель: зависимость количества чеков от количества сотрудников в магазине

# %%
df.describe()
# Out:
#        Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# count                  61.000000  61.0                           61.000000
# mean                   34.430949   1.0                            1.918033
# std                    20.930057   0.0                            0.862073
# min                     4.000000   1.0                            1.000000
# 25%                    22.000000   1.0                            1.000000
# 50%                    27.500000   1.0                            2.000000
# 75%                    40.780000   1.0                            2.000000
# max                   102.734951   1.0                            4.000000
#
#              Тип  Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# count  61.000000        61.000000                 61.000000    61.000000
# mean    1.114754         3.818033               7125.098361    95.976961
# ...

# %%
import seaborn as sns
corrmat = dfr.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %%
# Splitting the dataset into the Training set and Test set
df.shape
# Out:
# (61, 14)

# %%
X = df.iloc[:, [True,True,True,True,True,False,True,True,True,True,True,True,True,True]]
y = df['Количество чеков в месяц']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X
# Out:
#     Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   Тип  \
# 0                    9.000000     1                                   1    0
# 1                   22.000000     1                                   1    0
# 2                   13.000000     1                                   1    0
# 3                   18.000000     1                                   1    2
# 4                   25.000000     1                                   1    0
# ..                        ...   ...                                 ...  ...
# 64                  40.780000     1                                   3    1
# 65                  21.500000     1                                   2    1
# 66                 102.734951     1                                   1    2
# 67                  34.800000     1                                   2    0
# 68                  22.000000     1                                   2    1
#
# ...

# %%
#!pip install statsmodels

# %%
from sklearn.linear_model import LinearRegression

# %%
mr = LinearRegression().fit(X_train, y_train)

# Coefficient of determination R^2
mr.score(X_train, y_train).round(3)
# Out:
# 0.725

# %%
from sklearn.linear_model import LinearRegression

# %%
mr = LinearRegression().fit(X_train, y_train)

# Getting parameters
mr.coef_, mr.intercept_
# Out:
# (array([-2.91633015e+00, -1.33301947e-09,  3.13568561e+03,  7.89835058e+02,
#         -8.50199587e+01,  3.27665196e+01, -1.19928372e-01,  9.36617277e-02,
#          1.82120958e+02, -2.29799899e+02, -1.90416159e+03,  7.77171091e+02,
#          2.81187233e+02]),
#  -2013.0909713629635)

# %%
f1 = df['Количество чеков в месяц']

# %%
from sklearn.linear_model import LinearRegression
mr = LinearRegression().fit(X_train[f1], y_train)

mr.coef_, mr.intercept_
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12248/9417540.py in <module>
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 mr = LinearRegression().fit(X_train[f1], y_train)
#       3
#       4 mr.coef_, mr.intercept_
#
# ~\anaconda3\envs\Saridzha\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\Saridzha\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...
